# %%
import pandas as pd

# 构成DataFrame -- 创建数据集（学员成绩信息）

df1 = pd.DataFrame([
    {"姓名": "小王", "语文": 93, "数学": 99, "英语": 90},
    {"姓名": "小李", "语文": 88, "数学": 95, "英语": 87},
    {"姓名": "小张", "语文": 76, "数学": 82, "英语": 79},
    {"姓名": "小刘", "语文": 91, "数学": 88, "英语": 92},
    {"姓名": "小陈", "语文": 85, "数学": 90, "英语": 84},
    {"姓名": "小赵", "语文": 79, "数学": 86, "英语": 81},
    {"姓名": "小孙", "语文": 94, "数学": 97, "英语": 89},
    {"姓名": "小周", "语文": 82, "数学": 78, "英语": 85},
    {"姓名": "小吴", "语文": 90, "数学": 92, "英语": 88},
    {"姓名": "小郑", "语文": 87, "数学": 89, "英语": 91},
])

print(f"语文最高分：{df1['语文'].max()}, 最低分{df1['语文'].min()}, 平均分：{df1['语文'].mean()}")
print(f"语文最高分：{df1['数学'].max()}, 最低分{df1['数学'].min()}, 平均分：{df1['数学'].mean()}")
print(f"语文最高分：{df1['英语'].max()}, 最低分{df1['英语'].min()}, 平均分：{df1['英语'].mean()}")

# %%
df2 = pd.DataFrame({
    "姓名": ["小王", "小李", "小张", "小刘", "小陈", "小赵", "小孙", "小周", "小吴", "小郑"],
    "语文": [93, 88, 76, 91, 85, 79, 94, 82, 90, 87],
    "数学": [99, 95, 82, 88, 90, 86, 97, 78, 92, 89],
    "英语": [90, 87, 79, 92, 84, 81, 89, 85, 88, 91],
})
df2

# %%
df3 = pd.DataFrame([
    ("小王", 93, 99, 90),
    ("小李", 88, 95, 87),
    ("小张", 76, 82, 79),
    ("小刘", 91, 88, 92),
    ("小陈", 85, 90, 84),
    ("小赵", 79, 86, 81),
    ("小孙", 94, 97, 89),
    ("小周", 82, 78, 85),
    ("小吴", 90, 92, 88),
    ("小郑", 87, 89, 91),
], columns=["姓名", "语文", "数学", "英语"])
df3

# %%
df4 = pd.DataFrame([
    ["小王", 93, 99, 90],
    ["小李", 88, 95, 87],
    ["小张", 76, 82, 79],
    ["小刘", 91, 88, 92],
    ["小陈", 85, 90, 84],
    ["小赵", 79, 86, 81],
    ["小孙", 94, 97, 89],
    ["小周", 82, 78, 85],
    ["小吴", 90, 92, 88],
    ["小郑", 87, 89, 91],
], columns=["姓名", "语文", "数学", "英语"])
df4

# %%
df5 = pd.DataFrame([
    [93, 99, 90],
    [88, 95, 87],
    [76, 82, 79],
    [91, 88, 92],
    [85, 90, 84],
    [79, 86, 81],
    [94, 97, 89],
    [82, 78, 85],
    [90, 92, 88],
    [87, 89, 91],
], columns=["语文", "数学", "英语"], index=["小王", "小李", "小张", "小刘", "小陈", "小赵", "小孙", "小周", "小吴", "小郑"])
df5

# %%
print(df1.index)
print(df2.columns)
print(df3.values)
print(df4.size)
print(df4.shape)
print(df5.dtypes)
print(df5.shape)
# Out:
# RangeIndex(start=0, stop=10, step=1)
# Index(['姓名', '语文', '数学', '英语'], dtype='object')
# [['小王' 93 99 90]
#  ['小李' 88 95 87]
#  ['小张' 76 82 79]
#  ['小刘' 91 88 92]
#  ['小陈' 85 90 84]
#  ['小赵' 79 86 81]
#  ['小孙' 94 97 89]
#  ['小周' 82 78 85]
#  ['小吴' 90 92 88]
#  ['小郑' 87 89 91]]
# 40
# (10, 4)
# 语文    int64
# 数学    int64
# 英语    int64
# dtype: object
# (10, 3)
